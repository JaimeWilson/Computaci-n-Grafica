# %% [markdown]
# # Aula 4 Imagem editada pelo Jaime

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib notebook

# %%
def show_img(title,img):
    plt.figure(figsize = (8,6))
    plt.title(title)
    if img.ndim == 2:
        plt.imshow(img,cmap ='gray')
    else:
        plt.imshow(img)
    plt.show()

# %%
img = mpimg.imread('Pilotis_PUC.jpg')
show_img("Pilotis", img)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print(img.shape,img.dtype)
# Out:
# (183, 276, 3) uint8

# %%
img = img.astype('float32')

# %%
red = img[100,:,0]
green = img[100,:,1]
blue = img[100,:,2]
h,w = img.shape[:2]
x = np.arange(0.0,w,1)

# %%
def show_curves(x,y1,y2,y3):
    plt.figure(figsize=(8,5))
    plt.plot(x,y1,'r')
    if y2 is not None:
        plt.plot(x,y2,'g')
    if y3 is not None:
        plt.plot(x,y3,'b')
    plt.show()
    
show_curves(x,red, green,blue)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
gray = 0.2989*red+0.5870*green+0.1140*blue
show_curves(x,gray,None,None)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
from scipy import fftpack
Gray = fftpack.fft(gray)

# %%
print(Gray[1],Gray[-1])
# Out:
# (2483.2136+2572.4248j) (2483.2136-2572.4248j)

# %%
delta_f = 2*np.pi/w
f = np.arange(-np.pi,np.pi,delta_f)
Gray_shift = np.fft.fftshift(Gray)
P = np.abs(Gray_shift)
show_curves(f,P,None,None)
# Out:
# <img src="data:image/png;base64,..." width="800">
