# %% [markdown]
# ## CG20-Aula 4 - Imagem

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pim
import numpy as np
# %matplotlib notebook

# %%
img = pim.imread('Pilotis_PUC.jpg')

# %%
def show_img(title,imajen):
    plt.figure(figsize = (8,6))
    plt.title(title)
    if imajen.ndim == 2:
        plt.imshow(imajen, cmap ='gray')
    else:
        plt.imshow(imajen)
    plt.show()
show_img("Pilotis", img)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
h, w = img.shape[:2]
print(img.shape, f'h={h}, w={w}')
# Out:
# (183, 276, 3) h=183, w=276

# %%
def lum(rgb):
    return np.dot(rgb,[0.2126, 0.7152, 0.0722])

gray = lum(img)

# %%
print(gray.shape, img.shape)
# Out:
# (183, 276) (183, 276, 3)

# %%
show_img("Pil", gray)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
x = np.arange(0,w,1)
y = gray[100,:]

plt.figure(figsize=(8,4))
plt.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
